# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn import preprocessing, svm
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-f328692f040e> in <module>
#       1 import numpy as np
#       2 import pandas as pd
# ----> 3 import seaborn as sns
#       4 import matplotlib.pyplot as plt
#       5 from sklearn import preprocessing, svm
#
# ModuleNotFoundError: No module named 'seaborn'

# %%
pip install seaborn
# Out:
# Collecting seaborn
#   Downloading seaborn-0.11.1-py3-none-any.whl (285 kB)
# Requirement already satisfied: pandas>=0.23 in c:\users\jhanu\opencv\lib\site-packages (from seaborn) (1.2.4)
# Requirement already satisfied: matplotlib>=2.2 in c:\users\jhanu\opencv\lib\site-packages (from seaborn) (3.4.2)
# Requirement already satisfied: numpy>=1.15 in c:\users\jhanu\opencv\lib\site-packages (from seaborn) (1.20.3)
# Requirement already satisfied: scipy>=1.0 in c:\users\jhanu\opencv\lib\site-packages (from seaborn) (1.6.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\jhanu\opencv\lib\site-packages (from matplotlib>=2.2->seaborn) (1.3.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\jhanu\opencv\lib\site-packages (from matplotlib>=2.2->seaborn) (2.8.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\jhanu\opencv\lib\site-packages (from matplotlib>=2.2->seaborn) (0.10.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\jhanu\opencv\lib\site-packages (from matplotlib>=2.2->seaborn) (8.2.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\jhanu\opencv\lib\site-packages (from matplotlib>=2.2->seaborn) (2.4.7)
# Requirement already satisfied: six in c:\users\jhanu\opencv\lib\site-packages (from cycler>=0.10->matplotlib>=2.2->seaborn) (1.16.0)
# Requirement already satisfied: pytz>=2017.3 in c:\users\jhanu\opencv\lib\site-packages (from pandas>=0.23->seaborn) (2021.1)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.11.1
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 21.0.1; however, version 21.2.3 is available.
# You should consider upgrading via the 'c:\users\jhanu\opencv\scripts\python.exe -m pip install --upgrade pip' command.

# %%
df = pd.read_csv('bottle.csv')
df_binary = df[['Salnty', 'T_degC']]
# Out:
# c:\users\jhanu\opencv\lib\site-packages\IPython\core\interactiveshell.py:3169: DtypeWarning: Columns (47,73) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn import preprocessing, svm
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv('bottle.csv')
df_binary = df[['Salnty', 'T_degC']]
# Out:
# c:\users\jhanu\opencv\lib\site-packages\IPython\core\interactiveshell.py:3169: DtypeWarning: Columns (47,73) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df_binary.columns = ['Sal', 'Temp']

# %%
df_binary.head()
# Out:
#       Sal   Temp
# 0  33.440  10.50
# 1  33.440  10.46
# 2  33.437  10.46
# 3  33.420  10.45
# 4  33.421  10.45

# %%
sns.lmplot(x ="Sal", y ="Temp", data = df_binary, order = 2, ci = None)

# %%
df_binary.fillna(method ='ffill', inplace = True)
# Out:
# c:\users\jhanu\opencv\lib\site-packages\pandas\core\frame.py:4462: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().fillna(

# %%
X = np.array(df_binary['Sal']).reshape(-1, 1)
y = np.array(df_binary['Temp']).reshape(-1, 1)

# %%
df_binary.dropna(inplace = True)
# Out:
# <ipython-input-11-ad90ac1a68eb>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_binary.dropna(inplace = True)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size =
0.25)

# %%
regr = LinearRegression()
regr.fit(X_train, y_train)
print(regr.score(X_test, y_test))
# Out:
# 0.20836614787298247

# %%
y_pred = regr.predict(X_test)
plt.scatter(X_test, y_test, color ='b')
plt.plot(X_test, y_pred, color ='k')
plt.show()

# %%
df_binary500 = df_binary[:][:500]

# %%
sns.lmplot(x ="Sal", y ="Temp", data = df_binary500,order = 2, ci = None)

# %%
df_binary500.fillna(method ='ffill', inplace = True)
X = np.array(df_binary500['Sal']).reshape(-1, 1)
y = np.array(df_binary500['Temp']).reshape(-1, 1)
df_binary500.dropna(inplace = True)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size =
0.25)
regr = LinearRegression()
regr.fit(X_train, y_train)
print(regr.score(X_test, y_test))
# Out:
# 0.7918273762594817

# %%
y_pred = regr.predict(X_test)
plt.scatter(X_test, y_test, color ='b')
plt.plot(X_test, y_pred, color ='k')
plt.show()
